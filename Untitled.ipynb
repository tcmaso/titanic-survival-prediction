# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading data

# %%
train_file = r'C:\Users\Thomas\OneDrive\Desktop\titanic survival prediction\train.csv'
df_train = pd.read_csv(train_file, index_col=0)
df_train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
test_file = r'C:\Users\Thomas\OneDrive\Desktop\titanic survival prediction\test.csv'
df_test = pd.read_csv(test_file, index_col=0)
df_test
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...             ...                                           ...     ...
# 1305              3                            Spector, Mr. Woolf    male
# 1306              1                  Oliva y Ocana, Dona. Fermina  female
# 1307              3                  Saether, Mr. Simon Sivertsen    male
# 1308              3                           Ware, Mr. Frederick    male
# 1309              3                      Peter, Master. Michael J    male
#
#               Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# PassengerId
# 892          34.5      0      0              330911    7.8292   NaN        Q
# 893          47.0      1      0              363272    7.0000   NaN        S
# 894          62.0      0      0              240276    9.6875   NaN        Q
# 895          27.0      0      0              315154    8.6625   NaN        S
# 896          22.0      1      1             3101298   12.2875   NaN        S
# ...           ...    ...    ...                 ...       ...   ...      ...
# 1305          NaN      0      0           A.5. 3236    8.0500   NaN        S
# 1306         39.0      0      0            PC 17758  108.9000  C105        C
# 1307         38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308          NaN      0      0              359309    8.0500   NaN        S
# 1309          NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 10 columns]

# %%
gender_file = r'C:\Users\Thomas\OneDrive\Desktop\titanic survival prediction\gender_submission.csv'
df_gender = pd.read_csv(gender_file, index_col=0)
df_gender
# Out:
#              Survived
# PassengerId
# 892                 0
# 893                 1
# 894                 0
# 895                 0
# 896                 1
# ...               ...
# 1305                0
# 1306                1
# 1307                0
# 1308                0
# 1309                0
#
# [418 rows x 1 columns]

# %% [markdown]
# # Initial data review

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
df_train.describe().T
# Out:
#           count       mean        std   min      25%      50%   75%       max
# Survived  891.0   0.383838   0.486592  0.00   0.0000   0.0000   1.0    1.0000
# Pclass    891.0   2.308642   0.836071  1.00   2.0000   3.0000   3.0    3.0000
# Age       714.0  29.699118  14.526497  0.42  20.1250  28.0000  38.0   80.0000
# SibSp     891.0   0.523008   1.102743  0.00   0.0000   0.0000   1.0    8.0000
# Parch     891.0   0.381594   0.806057  0.00   0.0000   0.0000   0.0    6.0000
# Fare      891.0  32.204208  49.693429  0.00   7.9104  14.4542  31.0  512.3292

# %%
df_train.nunique()
# Out:
# Survived      2
# Pclass        3
# Name        891
# Sex           2
# Age          88
# SibSp         7
# Parch         7
# Ticket      681
# Fare        248
# Cabin       147
# Embarked      3
# dtype: int64

# %%
df_train.groupby(by='Survived').mean()
# Out:
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_3676\2367713770.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_train.groupby(by='Survived').mean()
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887
# 1         1.950292  28.343690  0.473684  0.464912  48.395408

# %%
df_train.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# Age, Cabin and Embarked features contain missing values.

# %% [markdown]
# # Data preprocessing

# %%
df_train_temp = df_train.copy()

# %%
df_train_temp
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
df_train_temp['Age'] = df_train_temp.groupby(['Sex', 'Pclass'])['Age'].apply(lambda x: x.fillna(x.median()))
# Out:
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_3676\220218208.py:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_train_temp['Age'] = df_train_temp.groupby(['Sex', 'Pclass'])['Age'].apply(lambda x: x.fillna(x.median()))

# %%
df_train_temp['Embarked'] = df_train_temp['Embarked'].fillna('S')

# %%
df_train_temp.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      0
# dtype: int64

# %% [markdown]
# # Feature engineering

# %%
df_train_temp['Cabin_group'] = df_train_temp['Cabin'].apply(lambda x: x[0] if pd.notnull(x) else 'Unknown')
df_train_temp['Cabin_group'][df_train_temp['Cabin_group']=='T'] = 'A' # T cabin close to a
# Out:
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_3676\1713590097.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train_temp['Cabin_group'][df_train_temp['Cabin_group']=='T'] = 'A' # T cabin close to a

# %%
df_train_temp['Cabin_group'].value_counts()
# Out:
# Unknown    687
# C           59
# B           47
# D           33
# E           32
# A           16
# F           13
# G            4
# Name: Cabin_group, dtype: int64

# %%
df_train_temp['Title'] = df_train_temp['Name'].str.split(', ', expand=True)[1].str.split('.', expand=True)[0]

# %%
df_train_temp['Title'].value_counts()
# Out:
# Mr              517
# Miss            182
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Mlle              2
# Major             2
# Col               2
# the Countess      1
# Capt              1
# Ms                1
# Sir               1
# Lady              1
# Mme               1
# Don               1
# Jonkheer          1
# Name: Title, dtype: int64

# %%
df_train_temp['Title'] = df_train_temp['Title'].replace(['Mr', 'Master'], 'Mr/Master')
df_train_temp['Title'] = df_train_temp['Title'].replace(['Miss', 'Mrs','Ms', 'Mlle', 'Lady', 'Mme', 'the Countess', 'Dona'], 'Miss/Mrs/Ms')
df_train_temp['Title'] = df_train_temp['Title'].replace(['Dr', 'Col', 'Major', 'Jonkheer', 'Capt', 'Sir', 'Don', 'Rev'], 'Dr/Military/Noble/Clergy')

# %%
df_train_temp['Title'].value_counts()
# Out:
# Mr/Master                   557
# Miss/Mrs/Ms                 313
# Dr/Military/Noble/Clergy     21
# Name: Title, dtype: int64

# %%
df_train_temp.drop(['Cabin', 'Name', 'Ticket'], axis=1, inplace=True)

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
columns_to_encode = ['Sex','Embarked','Cabin_group','Title']
for column in columns_to_encode:
    
    df_train_temp[column] = OrdinalEncoder().fit_transform(df_train_temp[[column]])

# %%
df_train_temp
# Out:
#              Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  \
# PassengerId
# 1                   0       3  1.0  22.0      1      0   7.2500       2.0
# 2                   1       1  0.0  38.0      1      0  71.2833       0.0
# 3                   1       3  0.0  26.0      0      0   7.9250       2.0
# 4                   1       1  0.0  35.0      1      0  53.1000       2.0
# 5                   0       3  1.0  35.0      0      0   8.0500       2.0
# ...               ...     ...  ...   ...    ...    ...      ...       ...
# 887                 0       2  1.0  27.0      0      0  13.0000       2.0
# 888                 1       1  0.0  19.0      0      0  30.0000       2.0
# 889                 0       3  0.0  21.5      1      2  23.4500       2.0
# 890                 1       1  1.0  26.0      0      0  30.0000       0.0
# 891                 0       3  1.0  32.0      0      0   7.7500       1.0
#
#              Cabin_group  Title
# PassengerId
# 1                    7.0    2.0
# 2                    2.0    1.0
# 3                    7.0    1.0
# 4                    2.0    1.0
# 5                    7.0    2.0
# ...                  ...    ...
# 887                  7.0    0.0
# 888                  1.0    1.0
# 889                  7.0    1.0
# 890                  2.0    2.0
# 891                  7.0    2.0
#
# [891 rows x 10 columns]

# %% [markdown]
# # EDA

# %%
df_train_temp.groupby(by='Cabin_group').mean()
# Out:
#              Survived    Pclass       Sex        Age     SibSp     Parch  \
# Cabin_group
# 0.0          0.437500  1.000000  0.937500  43.937500  0.125000  0.125000
# 1.0          0.744681  1.000000  0.425532  35.063830  0.361702  0.574468
# 2.0          0.593220  1.000000  0.542373  36.447797  0.644068  0.474576
# 3.0          0.757576  1.121212  0.454545  38.939394  0.424242  0.303030
# 4.0          0.750000  1.312500  0.531250  37.703125  0.312500  0.312500
# 5.0          0.615385  2.384615  0.615385  20.461538  0.538462  0.538462
# 6.0          0.500000  3.000000  0.000000  14.750000  0.500000  1.250000
# 7.0          0.299854  2.639010  0.684134  27.105167  0.547307  0.365357
#
#                    Fare  Embarked     Title
# Cabin_group
# 0.0           39.366144  1.125000  1.687500
# 1.0          113.505764  1.063830  1.297872
# 2.0          100.151341  1.254237  1.474576
# 3.0           57.244576  1.212121  1.424242
# 4.0           46.026694  1.656250  1.531250
# 5.0           18.696792  1.769231  1.615385
# 6.0           13.581250  2.000000  1.000000
# 7.0           19.157325  1.605531  1.646288

# %%
pearson_corr_series = pd.Series(df_train_temp.corr().iloc[0,1:], index=df_train_temp.corr().columns[1:])
pearson_corr_series
plt.figure(figsize=(20,1))
sns.heatmap([pearson_corr_series], xticklabels = pearson_corr_series.index, yticklabels=['Survived'], annot=True, cmap='Blues')
# Out:
# <AxesSubplot: >

# %%
abs(pearson_corr_series).sort_values(ascending=False).plot.bar()
# Out:
# <AxesSubplot: >

# %%
sns.heatmap(df_train_temp.corr(), annot=True, cmap='Blues')
# Out:
# <AxesSubplot: >

# %%
from sklearn.feature_selection import mutual_info_classif

# %%
mutual_info_series = pd.Series(mutual_info_classif(df_train_temp.drop('Survived', axis=1), df_train_temp['Survived']),
                               index=df_train_temp.drop('Survived', axis=1).columns)
mutual_info_series
plt.figure(figsize=(20,1))
sns.heatmap([mutual_info_series], annot=True, xticklabels=mutual_info_series.index, cmap='Blues')
# Out:
# <AxesSubplot: >

# %%
abs(mutual_info_series).sort_values(ascending=False).plot.bar()
# Out:
# <AxesSubplot: >

# %%
from sklearn.feature_selection import f_classif

# %%
anova_score, anova_p_value = f_classif(df_train_temp.drop('Survived', axis=1), df_train_temp['Survived'])
anova_score, anova_p_value
plt.figure(figsize=(20,1))
sns.heatmap([anova_score], annot=True, cmap='Blues', xticklabels=df_train_temp.drop('Survived', axis=1).columns)
plt.show()
plt.figure(figsize=(20,1))
sns.heatmap([anova_p_value], annot=True, cmap='Blues', xticklabels=df_train_temp.drop('Survived', axis=1).columns)
plt.show()

# %% [markdown]
# # Data preprocessing pipelines

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.base import BaseEstimator, TransformerMixin

# %%
class NewFeatures(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass
    def fit(self, X, y=None):
        return self
    def transform(self, X, y=None):
        X['Cabin_group'] = X['Cabin'].apply(lambda x: x[0] if pd.notnull(x) else 'Unknown')
        X['Cabin_group'][X['Cabin_group']=='T'] = 'A' # T cabin close to a
        
        X['Cabin_group'] = OrdinalEncoder(categories=[['A','B','C','D','E','F','G','Unknown']]).fit_transform(X[['Cabin_group']])
        
        X['Title'] = X['Name'].str.split(', ', expand=True)[1].str.split('.', expand=True)[0]
        X['Title'] = X['Title'].replace(['Mr', 'Master'], 'Mr/Master')
        X['Title'] = X['Title'].replace(['Miss', 'Mrs','Ms', 'Mlle', 'Lady', 'Mme', 'the Countess', 'Dona'], 'Miss/Mrs/Ms')
        X['Title'] = X['Title'].replace(['Dr', 'Col', 'Major', 'Jonkheer', 'Capt', 'Sir', 'Don', 'Rev'], 'Dr/Military/Noble/Clergy')
        
        X = X.join(pd.DataFrame(OneHotEncoder().fit_transform(X[['Title']]).toarray(), index=X.index))
        
        X.drop(['Cabin', 'Name', 'Title'], axis=1, inplace=True)
        return X

# %%
preprocessing_num_pipeline = Pipeline(steps=[
    ('fill_na', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

# %%
preprocessing_cat_pipeline = Pipeline(steps=[
    ('fill_na', SimpleImputer(strategy='most_frequent')),
    ('one_hot_encode', OneHotEncoder())
])

# %%
preprocessing_ord_pipeline = Pipeline(steps=[
    ('fill_na', SimpleImputer(strategy='most_frequent')),
    ('ordinal_encode', OrdinalEncoder())
])

# %%
num_columns = ['Age', 'Fare']
list(num_columns)
# Out:
# ['Age', 'Fare']

# %%
ord_columns = ['Pclass', 'SibSp', 'Parch']
ord_columns
# Out:
# ['Pclass', 'SibSp', 'Parch']

# %%
cat_columns = ['Sex', 'Embarked']
cat_columns
# Out:
# ['Sex', 'Embarked']

# %%
preprocessing_pipeline = ColumnTransformer([
    ('feature_engineering', NewFeatures(), ['Cabin', 'Name']),
    ('num_pipeline', preprocessing_num_pipeline, num_columns),
    ('ordinal_pipeline', preprocessing_ord_pipeline, ord_columns),
    ('cat_pipeline', preprocessing_cat_pipeline, cat_columns),
])

# %% [markdown]
# # Training/Test set initialization

# %%
from sklearn.model_selection import train_test_split

# %%
X_train = df_train.drop('Survived', axis=1).copy()
X_train.shape
# Out:
# (891, 10)

# %%
y_train = df_train['Survived'].copy()
y_train.shape
# Out:
# (891,)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=0)
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((712, 10), (179, 10), (712,), (179,))

# %%
X_test = df_test.copy()

X_test['Parch'][X_test['Parch']>6] = 6

X_test.shape
# Out:
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_3676\3827846989.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Parch'][X_test['Parch']>6] = 6
# (418, 10)

# %% [markdown]
# #

# %% [markdown]
# # Training algorithms

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, BaggingClassifier
from sklearn.tree import ExtraTreeClassifier, DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
import time
from sklearn.metrics import f1_score, confusion_matrix

# %%
algorithms = [RandomForestClassifier(), AdaBoostClassifier(), GradientBoostingClassifier(), BaggingClassifier(),
             ExtraTreeClassifier(), DecisionTreeClassifier(), KNeighborsClassifier(), LogisticRegression(),
             SGDClassifier(), SVC(), XGBClassifier()]

# %%
def prepare_model(X_train, y_train, algorithm):
    model = Pipeline(steps=[
        ('preprocessing', preprocessing_pipeline),
        ('model', algorithm)
    ])
    model.fit(X_train, y_train)
    return model

# %%
names = []
times = []
f1s = []
cms = []

for algorithm in algorithms:
    name = type(algorithm).__name__
    print(name)
    names.append(name)
    
    start_time = time.time()
    model = prepare_model(X_train, y_train, algorithm)
    pred = model.predict(X_val)
    end_time = time.time()
    time_duration = end_time - start_time
    times.append(time_duration)
    print(time_duration)
    
    f1 = f1_score(y_val, pred)
    f1s.append(f1)
    cm = confusion_matrix(y_val, pred)
    cms.append(cm)
# Out:
# RandomForestClassifier
# 0.15012168884277344
# AdaBoostClassifier
# 0.0856783390045166
# GradientBoostingClassifier
# 0.10019946098327637
# BaggingClassifier
# 0.04795193672180176
# ExtraTreeClassifier
# 0.030981779098510742
# DecisionTreeClassifier
# 0.03291749954223633
# KNeighborsClassifier
# 0.0401461124420166
# LogisticRegression
# 0.05896902084350586
# SGDClassifier
# 0.03293943405151367
# SVC
# 0.04606890678405762
# XGBClassifier
# 0.12285685539245605

# %%
results_dict = {'Name':names, 'Time':times, 'F1':f1s, 'CM':cms}

# %%
pd.DataFrame(results_dict).sort_values(by='F1', ascending=False)
# Out:
#                           Name      Time        F1                    CM
# 10               XGBClassifier  0.122857  0.809160  [[101, 9], [16, 53]]
# 0       RandomForestClassifier  0.150122  0.787879  [[99, 11], [17, 52]]
# 2   GradientBoostingClassifier  0.100199  0.768000  [[102, 8], [21, 48]]
# 3            BaggingClassifier  0.047952  0.744186  [[98, 12], [21, 48]]
# 6         KNeighborsClassifier  0.040146  0.742424  [[96, 14], [20, 49]]
# 1           AdaBoostClassifier  0.085678  0.739130  [[92, 18], [18, 51]]
# 9                          SVC  0.046069  0.736842  [[95, 15], [20, 49]]
# 7           LogisticRegression  0.058969  0.733813  [[91, 19], [18, 51]]
# 4          ExtraTreeClassifier  0.030982  0.712329  [[85, 25], [17, 52]]
# 5       DecisionTreeClassifier  0.032917  0.686131  [[89, 21], [22, 47]]
# 8                SGDClassifier  0.032939  0.500000  [[110, 0], [46, 23]]

# %%
model = prepare_model(X_train, y_train, XGBClassifier())
pred = model.predict(X_test)
X_test['Survived'] = pred
X_test
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...             ...                                           ...     ...
# 1305              3                            Spector, Mr. Woolf    male
# 1306              1                  Oliva y Ocana, Dona. Fermina  female
# 1307              3                  Saether, Mr. Simon Sivertsen    male
# 1308              3                           Ware, Mr. Frederick    male
# 1309              3                      Peter, Master. Michael J    male
#
#               Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# PassengerId
# 892          34.5      0      0              330911    7.8292   NaN        Q
# 893          47.0      1      0              363272    7.0000   NaN        S
# 894          62.0      0      0              240276    9.6875   NaN        Q
# 895          27.0      0      0              315154    8.6625   NaN        S
# 896          22.0      1      1             3101298   12.2875   NaN        S
# ...           ...    ...    ...                 ...       ...   ...      ...
# 1305          NaN      0      0           A.5. 3236    8.0500   NaN        S
# 1306         39.0      0      0            PC 17758  108.9000  C105        C
# 1307         38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308          NaN      0      0              359309    8.0500   NaN        S
# 1309          NaN      1      1                2668   22.3583   NaN        C
#
#              Survived
# PassengerId
# 892                 0
# 893                 0
# 894                 0
# 895                 1
# 896                 1
# ...               ...
# 1305                0
# 1306                1
# 1307                0
# 1308                0
# 1309                1
#
# [418 rows x 11 columns]

# %%
submission = X_test[['Survived']].reset_index().copy()
submission['Survived'] = submission['Survived'].astype('int')
submission.to_csv(r'submission.csv', index=False)

# %%
submission
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         1
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         1
#
# [418 rows x 2 columns]
