# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading data

# %%
train_file = r'C:\Users\Thomas\OneDrive\Desktop\titanic survival prediction\train.csv'
df_train = pd.read_csv(train_file, index_col=0)
df_train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
test_file = r'C:\Users\Thomas\OneDrive\Desktop\titanic survival prediction\test.csv'
df_test = pd.read_csv(test_file, index_col=0)
df_test
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...             ...                                           ...     ...
# 1305              3                            Spector, Mr. Woolf    male
# 1306              1                  Oliva y Ocana, Dona. Fermina  female
# 1307              3                  Saether, Mr. Simon Sivertsen    male
# 1308              3                           Ware, Mr. Frederick    male
# 1309              3                      Peter, Master. Michael J    male
#
#               Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# PassengerId
# 892          34.5      0      0              330911    7.8292   NaN        Q
# 893          47.0      1      0              363272    7.0000   NaN        S
# 894          62.0      0      0              240276    9.6875   NaN        Q
# 895          27.0      0      0              315154    8.6625   NaN        S
# 896          22.0      1      1             3101298   12.2875   NaN        S
# ...           ...    ...    ...                 ...       ...   ...      ...
# 1305          NaN      0      0           A.5. 3236    8.0500   NaN        S
# 1306         39.0      0      0            PC 17758  108.9000  C105        C
# 1307         38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308          NaN      0      0              359309    8.0500   NaN        S
# 1309          NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 10 columns]

# %%
gender_file = r'C:\Users\Thomas\OneDrive\Desktop\titanic survival prediction\gender_submission.csv'
df_gender = pd.read_csv(gender_file, index_col=0)
df_gender
# Out:
#              Survived
# PassengerId
# 892                 0
# 893                 1
# 894                 0
# 895                 0
# 896                 1
# ...               ...
# 1305                0
# 1306                1
# 1307                0
# 1308                0
# 1309                0
#
# [418 rows x 1 columns]

# %%
df_test = pd.concat([df_test, df_gender], axis=1)
df_test
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...             ...                                           ...     ...
# 1305              3                            Spector, Mr. Woolf    male
# 1306              1                  Oliva y Ocana, Dona. Fermina  female
# 1307              3                  Saether, Mr. Simon Sivertsen    male
# 1308              3                           Ware, Mr. Frederick    male
# 1309              3                      Peter, Master. Michael J    male
#
#               Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# PassengerId
# 892          34.5      0      0              330911    7.8292   NaN        Q
# 893          47.0      1      0              363272    7.0000   NaN        S
# 894          62.0      0      0              240276    9.6875   NaN        Q
# 895          27.0      0      0              315154    8.6625   NaN        S
# 896          22.0      1      1             3101298   12.2875   NaN        S
# ...           ...    ...    ...                 ...       ...   ...      ...
# 1305          NaN      0      0           A.5. 3236    8.0500   NaN        S
# 1306         39.0      0      0            PC 17758  108.9000  C105        C
# 1307         38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308          NaN      0      0              359309    8.0500   NaN        S
# 1309          NaN      1      1                2668   22.3583   NaN        C
#
#              Survived
# PassengerId
# 892                 0
# 893                 1
# 894                 0
# 895                 0
# 896                 1
# ...               ...
# 1305                0
# 1306                1
# 1307                0
# 1308                0
# 1309                0
#
# [418 rows x 11 columns]

# %% [markdown]
# # Initial data review

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
df_train.describe().T
# Out:
#           count       mean        std   min      25%      50%   75%       max
# Survived  891.0   0.383838   0.486592  0.00   0.0000   0.0000   1.0    1.0000
# Pclass    891.0   2.308642   0.836071  1.00   2.0000   3.0000   3.0    3.0000
# Age       714.0  29.699118  14.526497  0.42  20.1250  28.0000  38.0   80.0000
# SibSp     891.0   0.523008   1.102743  0.00   0.0000   0.0000   1.0    8.0000
# Parch     891.0   0.381594   0.806057  0.00   0.0000   0.0000   0.0    6.0000
# Fare      891.0  32.204208  49.693429  0.00   7.9104  14.4542  31.0  512.3292

# %%
df_train.nunique()
# Out:
# Survived      2
# Pclass        3
# Name        891
# Sex           2
# Age          88
# SibSp         7
# Parch         7
# Ticket      681
# Fare        248
# Cabin       147
# Embarked      3
# dtype: int64

# %%
df_train.groupby(by='Survived').mean()
# Out:
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_10536\2367713770.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_train.groupby(by='Survived').mean()
#           PassengerId    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0          447.016393  2.531876  30.626179  0.553734  0.329690  22.117887
# 1          444.368421  1.950292  28.343690  0.473684  0.464912  48.395408

# %%
df_train.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# Age, Cabin and Embarked features contain missing values.

# %%
columns_to_drop = ['Name', 'Ticket']

# %%
df_train.drop(columns_to_drop, axis=1)
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# PassengerId
# 1                   0       3    male  22.0      1      0   7.2500   NaN
# 2                   1       1  female  38.0      1      0  71.2833   C85
# 3                   1       3  female  26.0      0      0   7.9250   NaN
# 4                   1       1  female  35.0      1      0  53.1000  C123
# 5                   0       3    male  35.0      0      0   8.0500   NaN
# ...               ...     ...     ...   ...    ...    ...      ...   ...
# 887                 0       2    male  27.0      0      0  13.0000   NaN
# 888                 1       1  female  19.0      0      0  30.0000   B42
# 889                 0       3  female   NaN      1      2  23.4500   NaN
# 890                 1       1    male  26.0      0      0  30.0000  C148
# 891                 0       3    male  32.0      0      0   7.7500   NaN
#
#             Embarked
# PassengerId
# 1                  S
# 2                  C
# 3                  S
# 4                  S
# 5                  S
# ...              ...
# 887                S
# 888                S
# 889                S
# 890                C
# 891                Q
#
# [891 rows x 9 columns]

# %%
df_train.Cabin = df_train.Cabin.str.replace('\d+', '').astype(str).str[0]
# Out:
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_10536\276413786.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_train.Cabin = df_train.Cabin.str.replace('\d+', '').astype(str).str[0]

# %%
df_train.Cabin.value_counts()
# Out:
# n    687
# C     59
# B     47
# D     33
# E     32
# A     15
# F     13
# G      4
# T      1
# Name: Cabin, dtype: int64

# %%
df_train.Cabin[df_train.Cabin=='n'] = 'Unknown'
# Out:
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_10536\1424680709.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train.Cabin[df_train.Cabin=='n'] = 'Unknown'

# %%
df_train.Cabin.value_counts()
# Out:
# Unknown    687
# C           59
# B           47
# D           33
# E           32
# A           15
# F           13
# G            4
# T            1
# Name: Cabin, dtype: int64

# %%
df_train.groupby(by='Cabin').mean()
# Out:
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_10536\1041982272.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_train.groupby(by='Cabin').mean()
#          Survived    Pclass        Age     SibSp     Parch        Fare
# Cabin
# A        0.466667  1.000000  44.833333  0.133333  0.133333   39.623887
# B        0.744681  1.000000  34.955556  0.361702  0.574468  113.505764
# C        0.593220  1.000000  36.086667  0.644068  0.474576  100.151341
# D        0.757576  1.121212  39.032258  0.424242  0.303030   57.244576
# E        0.750000  1.312500  38.116667  0.312500  0.312500   46.026694
# F        0.615385  2.384615  19.954545  0.538462  0.538462   18.696792
# G        0.500000  3.000000  14.750000  0.500000  1.250000   13.581250
# T        0.000000  1.000000  45.000000  0.000000  0.000000   35.500000
# Unknown  0.299854  2.639010  27.555293  0.547307  0.365357   19.157325

# %% [markdown]
# # Data preprocessing pipelines

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder

# %%
preprocessing_num_pipeline = Pipeline(steps=[
    ('fill_na', SimpleImputer(strategy='mean'))
])

# %%
preprocessing_cat_pipeline = Pipeline(steps=[
    ('fill_na', SimpleImputer(strategy='most_frequent')),
    ('one_hot_encode', OneHotEncoder())
])

# %%
preprocessing_ord_pipeline = Pipeline(steps=[
    ('fill_na', SimpleImputer(strategy='most_frequent')),
    ('ordinal_encode', OrdinalEncoder())
])

# %%
num_columns = ['Age', 'Fare']
list(num_columns)
# Out:
# ['Age', 'Fare']

# %%
ord_columns = ['Pclass', 'SibSp', 'Parch']
ord_columns
# Out:
# ['Pclass', 'SibSp', 'Parch']

# %%
cat_columns = ['Sex', 'Embarked']
cat_columns
# Out:
# ['Sex', 'Embarked']

# %%
column_order = list(num_columns) + list(ord_columns) + list(cat_columns)

# %%
preprocessing_pipeline = ColumnTransformer([
    ('num_pipeline', preprocessing_num_pipeline, num_columns),
    ('ordinal_pipeline', preprocessing_ord_pipeline, ord_columns),
    ('cat_pipeline', preprocessing_cat_pipeline, cat_columns),
])

# %% [markdown]
# # Training/Test set initialization

# %%
X_train = df_train.drop('Survived', axis=1).copy()
X_train.shape
# Out:
# (891, 10)

# %%
y_train = df_train['Survived'].copy()
y_train.shape
# Out:
# (891,)

# %%
X_test = df_test.drop('Survived', axis=1).copy()
X_test.shape
# Out:
# (418, 10)

# %%
y_test = df_test['Survived'].copy()
y_test.shape
# Out:
# (418,)

# %% [markdown]
# #

# %%
X_train
# Out:
#              Pclass                                               Name  \
# PassengerId
# 1                 3                            Braund, Mr. Owen Harris
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                 3                             Heikkinen, Miss. Laina
# 4                 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                 3                           Allen, Mr. William Henry
# ...             ...                                                ...
# 887               2                              Montvila, Rev. Juozas
# 888               1                       Graham, Miss. Margaret Edith
# 889               3           Johnston, Miss. Catherine Helen "Carrie"
# 890               1                              Behr, Mr. Karl Howell
# 891               3                                Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# 1              male  22.0      1      0         A/5 21171   7.2500   NaN
# 2            female  38.0      1      0          PC 17599  71.2833   C85
# 3            female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 4            female  35.0      1      0            113803  53.1000  C123
# 5              male  35.0      0      0            373450   8.0500   NaN
# ...             ...   ...    ...    ...               ...      ...   ...
# 887            male  27.0      0      0            211536  13.0000   NaN
# 888          female  19.0      0      0            112053  30.0000   B42
# 889          female   NaN      1      2        W./C. 6607  23.4500   NaN
# 890            male  26.0      0      0            111369  30.0000  C148
# 891            male  32.0      0      0            370376   7.7500   NaN
#
#             Embarked
# PassengerId
# 1                  S
# 2                  C
# 3                  S
# 4                  S
# 5                  S
# ...              ...
# 887                S
# 888                S
# 889                S
# 890                C
# 891                Q
#
# [891 rows x 10 columns]

# %%
X_train = preprocessing_pipeline.fit_transform(X_train)
X_train
# Out:
# array([[22.        ,  7.25      ,  2.        , ...,  0.        ,
#          0.        ,  1.        ],
#        [38.        , 71.2833    ,  0.        , ...,  1.        ,
#          0.        ,  0.        ],
#        [26.        ,  7.925     ,  2.        , ...,  0.        ,
#          0.        ,  1.        ],
#        ...,
#        [29.69911765, 23.45      ,  2.        , ...,  0.        ,
#          0.        ,  1.        ],
#        [26.        , 30.        ,  0.        , ...,  1.        ,
#          0.        ,  0.        ],
#        [32.        ,  7.75      ,  2.        , ...,  0.        ,
#          1.        ,  0.        ]])

# %%
X_train.shape
# Out:
# (891, 10)

# %% [markdown]
# # Data exploratory

# %%
X_train = X_train.convert_dtypes()
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       891 non-null    Float64
#  1   Fare      891 non-null    Float64
#  2   Pclass    891 non-null    Int64
#  3   Name      891 non-null    string
#  4   Sex       891 non-null    string
#  5   SibSp     891 non-null    Int64
#  6   Parch     891 non-null    Int64
#  7   Ticket    891 non-null    string
#  8   Cabin     891 non-null    string
#  9   Embarked  891 non-null    string
# dtypes: Float64(2), Int64(3), string(5)
# memory usage: 74.1 KB

# %%
pearson_corr_series = pd.Series(df_train.corr().iloc[0,1:], index=df_train.corr().columns[1:])
pearson_corr_series
plt.figure(figsize=(20,1))
sns.heatmap([pearson_corr_series], xticklabels = pearson_corr_series.index, yticklabels=['Survived'], annot=True, cmap='Blues')
# Out:
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_10536\1998579718.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   pearson_corr_series = pd.Series(df_train.corr().iloc[0,1:], index=df_train.corr().columns[1:])
# <AxesSubplot: >

# %%
sns.heatmap(df_train.corr(), annot=True, cmap='Blues')
# Out:
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_10536\1805107695.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_train.corr(), annot=True, cmap='Blues')
# <AxesSubplot: >

# %%
df_train.corr()
# Out:
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_10536\299540020.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_train.corr()
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# Pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# Age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# SibSp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# Parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# Fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
type(df_train)
# Out:
# pandas.core.frame.DataFrame

# %%
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %%
sns.heatmap(X_train.corr(), annot=True, cmap='Blues')
# Out:
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_10536\349441345.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(X_train.corr(), annot=True, cmap='Blues')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [239], line 1
# ----> 1 sns.heatmap(X_train.corr(), annot=True, cmap='Blues')
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\matrix.py:543, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     540     ...     ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True)
#     541 """
#     542 # Initialize the plotter object
# --> 543 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     544                       annot_kws, cbar, cbar_kws, xticklabels,
#     545                       yticklabels, mask)
#     547 # Add the pcolormesh kwargs here
#     548 kwargs["linewidths"] = linewidths
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\matrix.py:163, in _HeatMapper.__init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     160 self.ylabel = ylabel if ylabel is not None else ""
#     162 # Determine good default values for the colormapping
# --> 163 self._determine_cmap_params(plot_data, vmin, vmax,
#     164                             cmap, center, robust)
#     166 # Sort out the annotations
#     167 if annot is None or annot is False:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\matrix.py:202, in _HeatMapper._determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     200         vmin = np.nanpercentile(calc_data, 2)
#     201     else:
# --> 202         vmin = np.nanmin(calc_data)
#     203 if vmax is None:
#     204     if robust:
#
# File <__array_function__ internals>:180, in nanmin(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\lib\nanfunctions.py:344, in nanmin(a, axis, out, keepdims, initial, where)
#     339     kwargs['where'] = where
#     341 if type(a) is np.ndarray and a.dtype != np.object_:
#     342     # Fast, but not safe for subclasses of ndarray, or object arrays,
#     343     # which do not implement isnan (gh-9009), or fmin correctly (gh-8975)
# --> 344     res = np.fmin.reduce(a, axis=axis, out=out, **kwargs)
#     345     if np.isnan(res).any():
#     346         warnings.warn("All-NaN slice encountered", RuntimeWarning,
#     347                       stacklevel=3)
#
# ValueError: zero-size array to reduction operation fmin which has no identity

# %%
X_train
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
from sklearn.feature_selection import mutual_info_classif

# %%
mutual_info_classif(X_train[['Pclass','SibSp', 'Fare']], y_train)
# Out:
# array([0.04711393, 0.03585701, 0.1351069 ])

# %%
X_train.select_dtypes(include='object').columns
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
mutual_info_classif(X_train[['Age']], y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [26], line 1
# ----> 1 mutual_info_classif(X_train[['Age']], y_train)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_mutual_info.py:464, in mutual_info_classif(X, y, discrete_features, n_neighbors, copy, random_state)
#     390 """Estimate mutual information for a discrete target variable.
#     391
#     392 Mutual information (MI) [1]_ between two random variables is a non-negative
#    (...)
#     461        of a Random Vector:, Probl. Peredachi Inf., 23:2 (1987), 9-16
#     462 """
#     463 check_classification_targets(y)
# --> 464 return _estimate_mi(X, y, discrete_features, True, n_neighbors, copy, random_state)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_mutual_info.py:256, in _estimate_mi(X, y, discrete_features, discrete_target, n_neighbors, copy, random_state)
#     199 def _estimate_mi(
#     200     X,
#     201     y,
#    (...)
#     206     random_state=None,
#     207 ):
#     208     """Estimate mutual information between the features and the target.
#     209
#     210     Parameters
#    (...)
#     254            Data Sets". PLoS ONE 9(2), 2014.
#     255     """
# --> 256     X, y = check_X_y(X, y, accept_sparse="csc", y_numeric=not discrete_target)
#     257     n_samples, n_features = X.shape
#     259     if isinstance(discrete_features, (str, bool)):
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:956, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     953 if y is None:
#     954     raise ValueError("y cannot be None")
# --> 956 X = check_array(
#     957     X,
#     958     accept_sparse=accept_sparse,
#     959     accept_large_sparse=accept_large_sparse,
#     960     dtype=dtype,
#     961     order=order,
#     962     copy=copy,
#     963     force_all_finite=force_all_finite,
#     964     ensure_2d=ensure_2d,
#     965     allow_nd=allow_nd,
#     966     ensure_min_samples=ensure_min_samples,
#     967     ensure_min_features=ensure_min_features,
#     968     estimator=estimator,
#     969 )
#     971 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#     973 check_consistent_length(X, y)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:792, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     786         raise ValueError(
#     787             "Found array with dim %d. %s expected <= 2."
#     788             % (array.ndim, estimator_name)
#     789         )
#     791     if force_all_finite:
# --> 792         _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     794 if ensure_min_samples > 0:
#     795     n_samples = _num_samples(array)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:114, in _assert_all_finite(X, allow_nan, msg_dtype)
#     107     if (
#     108         allow_nan
#     109         and np.isinf(X).any()
#     110         or not allow_nan
#     111         and not np.isfinite(X).all()
#     112     ):
#     113         type_err = "infinity" if allow_nan else "NaN, infinity"
# --> 114         raise ValueError(
#     115             msg_err.format(
#     116                 type_err, msg_dtype if msg_dtype is not None else X.dtype
#     117             )
#     118         )
#     119 # for object dtype data, we only check for NaNs (GH-13254)
#     120 elif X.dtype == np.dtype("object") and not allow_nan:
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
